# %% [markdown]
# Step 1. DATA IMPORT AND MERGE

# %%
import pandas as pd
import numpy as np

# %%
df_web_data_1 = pd.read_csv(r"C:\Users\chuan\Desktop\Ironhack\Week 5\week 5&6 Project\data\raw\df_final_web_data_pt_1.txt")
#display(df_web_data_1) 

#df_web_data_1['client_id'].nunique()

# %%
df_web_data_2 = pd.read_csv(r"C:\Users\chuan\Desktop\Ironhack\Week 5\week 5&6 Project\data\raw\df_final_web_data_pt_2.txt")
#display(df_web_data_2) 

#df_web_data_2['client_id'].nunique()

# %%
# 1. Merge web data 1&2 
df_web_data = pd.concat([df_web_data_1, df_web_data_2], ignore_index=True)

# 2. Merge df_web_data with df_experiment_client on client_id to match variation group 
df_experiment_client = pd.read_csv(r"C:\Users\chuan\Desktop\Ironhack\Week 5\week 5&6 Project\data\raw\df_final_experiment_clients.txt")
df_final_web_data = df_web_data.merge(df_experiment_client[['client_id', 'Variation']], on='client_id', how='left')

# Group by client_id and variation, then count occurrences
variation_counts = df_final_web_data.groupby(['client_id', 'Variation']).size().reset_index(name='count')

# Display the first few rows
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time Variation
# 0            step_3  2017-04-17 15:27:07      Test
# 1            step_2  2017-04-17 15:26:51      Test
# 2            step_3  2017-04-17 15:19:22      Test
# 3            step_2  2017-04-17 15:19:13      Test
# 4            step_3  2017-04-17 15:18:04      Test
# ...             ...                  ...       ...
# 755400        start  2017-05-24 18:46:10       NaN
# 755401        start  2017-05-24 18:45:29       NaN
# 755402       step_1  2017-05-24 18:44:51       NaN
# 755403        start  2017-05-24 18:44:34       NaN
# 755404        start  2017-06-03 12:17:09       NaN
#
# [755405 rows x 6 columns]

# %%
# Basic checks
# unique id 70609
df_final_web_data['client_id'].nunique()

# data types
#df_final_web_data.dtypes
# Out:
# 120157

# %% [markdown]
# Step 2. DATA CLEANING AND WRANGLING

# %%
# 2. Data cleaning and wrangling 

# 2.1 Map the consistancy of the name of columns 
#df_final_web_data.columns = df_web_data.columns.str.replace('_', ' ').str.title()

# 2.2 Drop Duplicates 
df_final_web_data.duplicated().any() #False, no duplicated rows

# 2.3 Check missing values 
df_final_web_data.isnull().sum() #variation missing values 20109/434096 --> dublicates id in repeat steps
# Out:
# client_id            0
# visitor_id           0
# visit_id             0
# process_step         0
# date_time            0
# Variation       434096
# dtype: int64

# %%
# 2.4 Step counts visual 
step_counts = df_final_web_data.groupby(['client_id', 'process_step']).size()

step_counts_unstacked = step_counts.unstack(fill_value=0)

step_counts_unstacked
# Out:
# process_step  confirm  start  step_1  step_2  step_3
# client_id
# 169                 1      1       1       1       1
# 336                 0      2       0       0       0
# 546                 1      1       1       1       1
# 555                 1      1       1       1       1
# 647                 1      1       1       1       1
# ...               ...    ...     ...     ...     ...
# 9999729             1      4       3       2       1
# 9999768             1      3       3       3       2
# 9999832             0      1       1       0       0
# 9999839             1      2       1       1       1
# 9999875             1      1       2       1       1
#
# [120157 rows x 5 columns]

# %% [markdown]
# Step 3. DEFINE METRICS AND HYPOTHESIS TESTING

# %% [markdown]
# METRICS 1. COMPLETION RATE

# %%
import pandas as pd

# Sort by client_id and date_time
df_final_web_data = df_final_web_data.sort_values(by=['client_id', 'date_time'])

# Function to calculate the completion rate using unique client IDs
def calculate_completion_rate(df_final_web_data, completion_step='confirm'):
    # Ensure 'date_time' is in datetime format
    df_final_web_data['date_time'] = pd.to_datetime(df_final_web_data['date_time'])
    
    # Identify unique clients who completed the process
    completed_clients = df_final_web_data[df_final_web_data['process_step'] == completion_step]['client_id'].unique()
    
    # Mark clients who completed the process
    df_final_web_data['confirm'] = df_final_web_data['client_id'].isin(completed_clients)
    
    # Drop duplicates to ensure unique client IDs
    df_unique_clients = df_final_web_data.drop_duplicates(subset='client_id', keep='first')
    
    # Group by variation to count total and completed clients
    completion_counts = df_unique_clients.groupby('Variation')['confirm'].agg(['sum', 'count'])
    completion_counts.columns = ['completed_clients', 'total_clients']
    
    # Calculate completion rate
    completion_counts['completion_rate'] = completion_counts['completed_clients'] / completion_counts['total_clients']
    
    return completion_counts

# Calculate the completion rate

completion_rate_df = calculate_completion_rate(df_final_web_data)

display(completion_rate_df)

# total_clients with unique_id = 50500
# Out:
#            completed_clients  total_clients  completion_rate
# Variation
# Control                15434          23532         0.655873
# Test                   18687          26968         0.692932

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.13.1

# %%
# 3.1.2 --> Set the hypothesis for Hypothis 1 --> if completion rate is equal?
# H0: The completion rate for the Test group (new design) = the completion rate for the Control group (old design).
# H1: The completion rate for the Test group (new design) != the completion rate for the Control group (old design).

#BY USING TWO SAMPLE PROPORTION Z-TEST 

import pandas as pd
from statsmodels.stats.proportion import proportions_ztest

# Number of successes (completed clients) in each group
successes = completion_rate_df['completed_clients'].values

# Number of observations (total clients) in each group
nobs = completion_rate_df['total_clients'].values

# Conduct the two-proportion z-test
z_stat, p_value = proportions_ztest(successes, nobs)

# Output the results
print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Check if p-value is less than alpha (e.g., 0.05) for significance
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: The completion rate for the Test group is not equal to the completion rate for the Control group.")
else:
    print("Fail to reject null hypothesis: There is no significant difference in completion rates between the Test and Control groups.")
# Out:
# Z-statistic: -8.8745141890702
# P-value: 7.023933247581432e-19
# Reject null hypothesis: The completion rate for the Test group is not equal to the completion rate for the Control group.

# %%
# 3.1.2 --> Set the hypothesis for Hypothis 1 --> Completion Rate with a Cost-Effectiveness Threshold 5%.
# H0: The completion rate for the Test group (new design) is equal to or less than the completion rate for the Control group (old design) increased by 5%.
# H1: The completion rate for the Test group (new design) is greater than the completion rate for the Control group (old design) increased by 5%.

import pandas as pd
from statsmodels.stats.proportion import proportions_ztest

# Example completion rates (calculated previously)
completion_rate_df = pd.DataFrame({
    'variation': ['Control', 'Test'],
    'completed_clients': [15434, 18687], 
    'total_clients': [23532, 26968]  
})

# Calculate the completion rate for the Control group and increase by 5%
control_completion_rate = completion_rate_df.loc[completion_rate_df['variation'] == 'Control', 'completed_clients'].values[0] / completion_rate_df.loc[completion_rate_df['variation'] == 'Control', 'total_clients'].values[0]
adjusted_control_completion_rate = control_completion_rate + 0.05

# Number of successes (completed clients) in each group
successes = completion_rate_df['completed_clients'].values

# Number of observations (total clients) in each group
nobs = completion_rate_df['total_clients'].values

# Calculate the z-statistic and p-value for the one-sided test
z_stat, p_value = proportions_ztest(successes, nobs, value=adjusted_control_completion_rate, alternative='larger')

# Output the results
print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Check if p-value is less than alpha (e.g., 0.05) for significance
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: The completion rate for the Test group is greater than the completion rate for the Control group increased by 5%.")
else:
    print("Fail to reject null hypothesis: The completion rate for the Test group is not significantly greater than the completion rate for the Control group increased by 5%.")
# Out:
# Z-statistic: -177.90747247928385
# P-value: 1.0
# Fail to reject null hypothesis: The completion rate for the Test group is not significantly greater than the completion rate for the Control group increased by 5%.

# %% [markdown]
# METRICS 2. TIME SPENT ON EACH STEP

# %%
# 3.2 TIME SPENT ON EACH STEP
# 3.2.1 Calculate time spent on each step 

import pandas as pd
from scipy.stats import ttest_ind

# Filter Data for Control and Test Groups
control_data = df_final_web_data[df_final_web_data['Variation'] == 'Control']
test_data = df_final_web_data[df_final_web_data['Variation'] == 'Test']

# Calculate Time Differences Between Consecutive Steps
control_data['time_diff'] = control_data.groupby('client_id')['date_time'].diff()
test_data['time_diff'] = test_data.groupby('client_id')['date_time'].diff()

# Remove NaN values resulting from the diff() operation
control_data = control_data.dropna(subset=['time_diff'])
test_data = test_data.dropna(subset=['time_diff'])

# Initialize lists to store results
steps = []
t_statistics = []
p_values = []

# Perform a two-sample t-test for each step
for step in control_data['process_step'].unique():
    control_step_time = control_data[control_data['process_step'] == step]['time_diff'].dt.total_seconds()
    test_step_time = test_data[test_data['process_step'] == step]['time_diff'].dt.total_seconds()
    
    # Perform t-test
    t_stat, p_val = ttest_ind(control_step_time, test_step_time, equal_var=False)
    
    # Store results
    steps.append(step)
    t_statistics.append(t_stat)
    p_values.append(p_val)

# Create a DataFrame to display the results
results_df = pd.DataFrame({
    'Step': steps,
    'T-Statistic': t_statistics,
    'P-Value': p_values
})

# Print or visualize the results
display(results_df)
# Out:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_4796\3452451652.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control_data['time_diff'] = control_data.groupby('client_id')['date_time'].diff()
# C:\Users\chuan\AppData\Local\Temp\ipykernel_4796\3452451652.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['time_diff'] = test_data.groupby('client_id')['date_time'].diff()
#       Step  T-Statistic       P-Value
# 0   step_1     1.035563  3.004104e-01
# 1   step_2    -1.926237  5.408386e-02
# 2   step_3    -0.415325  6.779058e-01
# 3    start    11.976639  5.247120e-33
# 4  confirm    -7.901798  2.821152e-15

# %%
# 3.2.2 Set the hypothesis for Hypothis 2 --> time spent on each step: --> comapre mean of each step of group/test 
# H0: There is no significant difference in time spent on each step between the Test and Control groups.
# H1: There is significant difference in time spent on each step between the Test and Control groups.

# Check if p-value is less than alpha (e.g., 0.05) for significance
alpha = 0.05
results_df['Significant'] = results_df['P-Value'] < alpha

print("\nHypothesis Testing Results:")
display(results_df)
# Out:
# Hypothesis Testing Results:
#       Step  T-Statistic       P-Value  Significant
# 0   step_1     1.035563  3.004104e-01        False
# 1   step_2    -1.926237  5.408386e-02        False
# 2   step_3    -0.415325  6.779058e-01        False
# 3    start    11.976639  5.247120e-33         True
# 4  confirm    -7.901798  2.821152e-15         True

# %% [markdown]
# CONCLUSION:
# From the results:
#
# step_1: No significant difference in time spent between the control and test groups.
#
# step_2: No significant difference, but results are close to significance, suggesting a potential trend.
#
# step_3: No significant difference in time spent between the control and test groups.
#
# start: Significant increase in time spent in the test group.
#
# confirm: Significant decrease in time spent in the test group.

# %% [markdown]
# METRICS 3. ERROR RATES

# %%
# 3.3 ERROR RATES 
# 3.3.1 Calculate error rates
# Assign numeric values to process steps to identify backward movements
step_mapping = {
    'start': 1,
    'step_1': 2,
    'step_2': 3,
    'step_3': 4,
    'confirm': 5
}
df_final_web_data['step_num'] = df_web_data['process_step'].map(step_mapping)

# Calculate the difference in step numbers to identify backward steps
df_final_web_data['step_diff'] = df_final_web_data.groupby(['client_id', 'visit_id'])['step_num'].diff()

# Identify backward steps (where step_diff is negative)
df_final_web_data['backward'] = df_final_web_data['step_diff'] < 0

# Calculate the total steps and backward steps for each group
error_stats = df_final_web_data.groupby('Variation').agg(
    total_steps=('process_step', 'count'),
    backward_steps=('backward', 'sum')
).reset_index()

# Calculate the error rate for each group
error_stats['error_rate'] = error_stats['backward_steps'] / error_stats['total_steps']

display(error_stats)
# Out:
#   Variation  total_steps  backward_steps  error_rate
# 0   Control       143462            9615    0.067021
# 1      Test       177847           16247    0.091354

# %%
# 3.3.2 Set the hypothesis for Hypothis 3 --> error rates 
# H0: There is no significant difference in error rates between the Test and Control groups.
# H1: There is a significant difference in error rates between the Test and Control groups.

from statsmodels.stats.proportion import proportions_ztest

# Number of backward steps (errors) in each group
backward_steps = error_stats['backward_steps'].values

# Total number of steps in each group
total_steps = error_stats['total_steps'].values

# Perform the two-proportion z-test
stat, p_value = proportions_ztest(backward_steps, total_steps)

# Display the results
print(f"Z-test statistic: {stat}, p-value: {p_value}")

# Check if p-value is less than alpha (e.g., 0.05) for significance
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in error rates between the Test and Control groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in error rates between the Test and Control groups.")
# Out:
# Z-test statistic: -25.204049796278067, p-value: 3.616424613022473e-140
# Reject the null hypothesis: There is a significant difference in error rates between the Test and Control groups.

# %%
# 3.3.2 Set the hypothesis for Hypothis 3 --> Completion Rate with a Cost-Effectiveness Threshold 5%.
# H0: The error rates of Test group is greater than Control group increased by 5% 
# H1: The error rates of Test group is equal to or less than Control group increased by 5% 

# Adjust the control group's error rate by 5%
error_rate_control = error_stats.loc[error_stats['Variation'] == 'Control', 'error_rate'].values[0]
error_rate_test = error_stats.loc[error_stats['Variation'] == 'Test', 'error_rate'].values[0]
adjusted_error_rate_control = error_rate_control * 1.05

# Calculate the number of errors and total steps
errors = error_stats['backward_steps'].values
nobs = error_stats['total_steps'].values

# Conduct the one-sided two-proportion z-test
z_stat, p_value = proportions_ztest([errors[1], errors[0]], [nobs[1], nobs[0]], alternative='smaller')

# Output the results
print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Check if p-value is less than alpha (e.g., 0.05) for significance
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: The error rate for the Test group is equal to or less than the error rate for the Control group increased by 5%.")
else:
    print("Fail to reject null hypothesis: The error rate for the Test group is greater than the error rate for the Control group increased by 5%.")
# Out:
# Z-statistic: 25.204049796278067
# P-value: 1.0
# Fail to reject null hypothesis: The error rate for the Test group is greater than the error rate for the Control group increased by 5%.

# %%
#df_final_web_data.head(20)

# %% [markdown]
# HYPOTHESIS TESTING RESULT
#
# 1. COMPLETION RATE
#
# 1.1
#
# H0: Completion rate of Test group = Control group.
#
# H1: Completion rate of Test group ! = Control group.
#
# RESULT: REJECT --> Completion rate !=  --> there is impact of new interface
#
# 1.2
#
# H0: Completion rate of Test group =< Control group increased by 5%.
#
# H1: Completion rate of Test group > Control group increased by 5%.
#
# RESULT: FAIL TO REJECT --> Completion rate of Test group =< Control group increased by 5% --> no effective increase (<5%) ROI very low
#
# 2. TIME SPENT ON EACH STEP
#
# H0: There is no significant difference in time spent on each step between the Test and Control groups
#
# H1: There is significant difference in time spent on each step between the Test and Control groups
#
# RESULTS: FAIL TO REJECT -->
#
# step_1: No significant difference in time spent between the control and test groups.
#
# step_2: No significant difference, but results are close to significance, suggesting a potential trend.
#
# step_3: No significant difference in time spent between the control and test groups.
#
# start: Significant increase in time spent in the test group.
#
# confirm: Significant decrease in time spent in the test group.
#
# --> New interface attracted more clients but not to the final step --> potential reason: too complicated operation?
#
# 3. ERROR RATE
#
# 3.1
#
# H0: Error rate of Test group = Control group.
#
# H1: Error rate of Test group ! = Control group.
#
# RESULT: REJECT --> Error rate !=
#
# 3.2
#
# H0: Error rate of Test group > Control group increased by 5%.
#
# H1: Error rate of Test group <= Control group increased by 5%.
#
# RESULT: FAIL TO REJECTED --> Error rate of Test group > Control group increased by 5% --> New interface caused more error rates

# %%
import pandas as pd

# Sample data (replace with actual data loading)
# df_final_web_data = pd.read_csv('path_to_your_web_data.csv')

# Filter data for Control and Test groups
control_data = df_final_web_data[df_final_web_data['Variation'] == 'Control']
test_data = df_final_web_data[df_final_web_data['Variation'] == 'Test']

# Define step order
step_order = ['start', 'step_1', 'step_2', 'step_3', 'confirm']

# Function to count step sequences
def count_step_sequences(df, step_order):
    df['next_step'] = df.groupby('client_id')['process_step'].shift(-1)
    step_sequences = df.dropna(subset=['next_step']).groupby(['process_step', 'next_step']).size().unstack(fill_value=0)
    step_sequences = step_sequences.reindex(index=step_order, columns=step_order, fill_value=0)
    return step_sequences

# Get step sequences for both groups
control_sequences = count_step_sequences(control_data, step_order)
test_sequences = count_step_sequences(test_data, step_order)

print("Control Group Step Sequences:")
display(control_sequences)

print("\nTest Group Step Sequences:")
display(test_sequences)
# Out:
# Control Group Step Sequences:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_4796\2344923173.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['next_step'] = df.groupby('client_id')['process_step'].shift(-1)
# C:\Users\chuan\AppData\Local\Temp\ipykernel_4796\2344923173.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['next_step'] = df.groupby('client_id')['process_step'].shift(-1)
# next_step     start  step_1  step_2  step_3  confirm
# process_step
# start         15754   25904     127     190       51
# step_1         3559    1327   22419      37      101
# step_2         1346    1409     960   21394       43
# step_3         1902     835    2372    1016    15331
# confirm        1681     101       0     130     1941
# Test Group Step Sequences:
# next_step     start  step_1  step_2  step_3  confirm
# process_step
# start         16554   33520     365     370       88
# step_1         7616    1700   27652      43      103
# step_2         2138    3174     666   24419       22
# step_3         2883     237    2298    1006    18450
# confirm         663      48       2      29     6833

# %%
import scipy.stats as stats

# Calculate number of steps taken by each user
control_steps = control_data.groupby('client_id').size()
test_steps = test_data.groupby('client_id').size()

# Perform t-test
t_stat, p_val = stats.ttest_ind(control_steps, test_steps, equal_var=False)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -13.340635866513672
# P-value: 1.5765962438584306e-40

# %%
# Filter by process step 
#filtered_df_final_web_data_start = df_final_web_data[df_final_web_data['process_step'] == 'start']
#filtered_df_final_web_data_start
#filtered_df_final_web_data_start['Client Id'].nunique()

# %%
#filtered_df_web_data_confirm = df_web_data[df_web_data['Process Step'] == 'confirm']

#filtered_df_web_data_confirm

#filtered_df_web_data_confirm['Client Id'].nunique()

# %%
# Hypothesis distribution 1

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest


completion_rate_df = pd.DataFrame({
    'completed_clients': [18687, 15434], 
    'total_clients': [26968, 23532] 
})

# Number of successes (completed clients) in each group
successes = completion_rate_df['completed_clients'].values

# Number of observations (total clients) in each group
nobs = completion_rate_df['total_clients'].values

# Conduct the two-proportion z-test
z_stat, p_value = proportions_ztest(successes, nobs)

# Output the results
print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Define the range for the x-axis
x = np.linspace(-4, 4, 1500)
y = norm.pdf(x, 0, 1)  # 标准正态分布的PDF


plt.plot(x, y, label='Standard Normal Distribution')
plt.axvline(z_stat, color='red', linestyle='--', label=f'Z-statistic = {z_stat:.2f}')


alpha = 0.05
z_critical = norm.ppf(1 - alpha/2)


x_fill_left = np.linspace(-4, -z_critical, 100)
y_fill_left = norm.pdf(x_fill_left, 0, 1)
plt.fill_between(x_fill_left, y_fill_left, color='gray', alpha=0.5, label=f'α/2 = {alpha/2:.2f}')


x_fill_right = np.linspace(z_critical, 4, 100)
y_fill_right = norm.pdf(x_fill_right, 0, 1)
plt.fill_between(x_fill_right, y_fill_right, color='gray', alpha=0.5)


plt.text(z_stat + 0.1, 0.25, f'P-value = {p_value:.2e}', fontsize=10)


cdf_value = norm.cdf(z_stat)
plt.text(z_stat + 0.1, 0.2, f'CDF = {cdf_value:.3f}', fontsize=10)


plt.axvline(-z_critical, color='blue', linestyle='--', label=f'Critical value = {-z_critical:.2f}')
plt.axvline(z_critical, color='blue', linestyle='--', label=f'Critical value = {z_critical:.2f}')


plt.legend()
plt.xlabel('Z')
plt.ylabel('Density')
plt.title('Hypothesis Results: Equality of Completion Rate')




plt.savefig('z_test_result.png')

plt.show()
# Out:
# Z-statistic: 8.8745141890702
# P-value: 7.023933247581432e-19

# %%
# Hypothesis distribution 3

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from statsmodels.stats.proportion import proportions_ztest

# Example data (replace with your own data)
backward_steps = error_stats['backward_steps'].values  # Backward steps for Control and Test groups
total_steps = error_stats['total_steps'].values  # Total steps for Control and Test groups

# Perform the two-proportion z-test
stat, p_value = proportions_ztest(backward_steps, total_steps)

# Define the range for the x-axis (use a larger range to include critical values)
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)  # Standard normal distribution PDF

# Plot standard normal distribution
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution')

# Plot the critical region for one-sided test (right-tailed)
alpha = 0.05
z_critical = norm.ppf(1 - alpha)  # One-sided critical value for alpha = 0.05
plt.fill_between(x[x > z_critical], norm.pdf(x[x > z_critical]), color='gray', alpha=0.5, label=f'α = {alpha}')

# Plot z-statistic
plt.axvline(stat, color='red', linestyle='--', label=f'Z-statistic = {stat:.2f}')

# Annotate p-value
plt.text(stat + 0.1, 0.2, f'P-value = {p_value:.2e}', fontsize=10)

# Labels and legend
plt.legend()
plt.xlabel('Z')
plt.ylabel('Density')
plt.title('Hypothesis Results: Equality of Error Rates')

# Show the plot

plt.savefig('error rates.png')

plt.show()

# %%
#df_final_web_data.to_csv('df_final_web', index=False)
#print("df_final_web_data saved successfully to 'Vanguard_web_data_quantitative.csv'")
